# %%
from textgenrnn import textgenrnn

textgen = textgenrnn()

# %%
textgen.reset
textgen.train_from_file('beyondgoodandevil.txt', new_model=True, batch_size=128, num_epochs=5, gen_epochs=5)
textgen.generate(1, temperature=1.5)
# Out:
# 6,058 texts collected.
# Training new model w/ 2-layer, 128-cell LSTMs
# Training on 381,370 character sequences.
# Epoch 1/5
# 2979/2979 [==============================] - 34s 12ms/step - loss: 2.2464
# Epoch 2/5
# 2979/2979 [==============================] - 33s 11ms/step - loss: 1.6414
# Epoch 3/5
# 2979/2979 [==============================] - 33s 11ms/step - loss: 1.4854
# Epoch 4/5
# 2979/2979 [==============================] - 34s 11ms/step - loss: 1.3934
# Epoch 5/5
# 2979/2979 [==============================] - 34s 11ms/step - loss: 1.3202
# ####################
# Temperature: 0.2
# ####################
#
#
#
#
# self-contrary and profound and also the most dangerous and morality, and the world and developments of the strength of the strange of the spirit and perhaps the proper with the profound and problem of the signification of the strange of the strong and contemptible to the most discoverer of the cont
#
# ####################
# Temperature: 0.5
# ####################
# ...

# %%
print(textgen.model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input (InputLayer)              (None, 40)           0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 40, 100)      7900        input[0][0]
# __________________________________________________________________________________________________
# rnn_1 (CuDNNLSTM)               (None, 40, 128)      117760      embedding[0][0]
# __________________________________________________________________________________________________
# rnn_2 (CuDNNLSTM)               (None, 40, 128)      132096      rnn_1[0][0]
# __________________________________________________________________________________________________
# rnn_concat (Concatenate)        (None, 40, 356)      0           embedding[0][0]
# ...

# %%
textgen.reset()
textgen.train_from_file('shakesonnets.txt',
                        new_model=True,
                        rnn_bidirectional=True,
                        rnn_size=64,
                        dim_embeddings=300,
                        num_epochs=5)

print(textgen.model.summary())
# Out:
# 2,617 texts collected.
# Training new model w/ 2-layer, 64-cell Bidirectional LSTMs
# Training on 95,688 character sequences.
# Epoch 1/5
# 747/747 [==============================] - 14s 18ms/step - loss: 2.2318
# ####################
# Temperature: 0.2
# ####################
#
#
#
#
# And the will that the and thy self that bear bear and straght,
#
# ####################
# Temperature: 0.5
# ####################
# In thy sumpe bost thy cound all see be deest,
#
# And in make and thy sear that that as so deart?
#
# I and thy stand sumblies to my sweear troth's stree:
#
# ####################
# Temperature: 1.0
# ####################
# Lin, and and eyes brosty best,  by harth ence wime ost.
#
# Dust a fare thy lixe cer tmason doth dive?
#
#
#
# Epoch 2/5
# 747/747 [==============================] - 13s 17ms/step - loss: 1.7713
# ####################
# Temperature: 0.2
# ####################
# ...
